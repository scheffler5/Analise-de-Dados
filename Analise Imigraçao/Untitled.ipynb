# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
arquivo = pd.read_csv("imigrantes_canada.csv")
arquivo
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %%
arquivo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   País        195 non-null    object
#  1   Continente  195 non-null    object
#  2   Região      195 non-null    object
#  3   1980        195 non-null    int64
#  4   1981        195 non-null    int64
#  5   1982        195 non-null    int64
#  6   1983        195 non-null    int64
#  7   1984        195 non-null    int64
#  8   1985        195 non-null    int64
#  9   1986        195 non-null    int64
#  10  1987        195 non-null    int64
#  11  1988        195 non-null    int64
#  12  1989        195 non-null    int64
#  13  1990        195 non-null    int64
#  14  1991        195 non-null    int64
#  15  1992        195 non-null    int64
#  16  1993        195 non-null    int64
#  17  1994        195 non-null    int64
#  18  1995        195 non-null    int64
# ...

# %%
arquivo.set_index("País", inplace=True)
arquivo
# Out:
#                 Continente            Região  1980  1981  1982  1983  1984  \
# País
# Afeganistão           Ásia       Sul da Ásia    16    39    39    47    71
# Albânia             Europa     Sul da Europa     1     0     0     0     0
# Argélia             África   Norte da África    80    67    71    69    63
# Samoa Americana    Oceânia         Polinésia     0     1     0     0     0
# Andorra             Europa     Sul da Europa     0     0     0     0     0
# ...                    ...               ...   ...   ...   ...   ...   ...
# Vietnã                Ásia  Sudeste Asiático  1191  1829  2162  3404  7583
# Saara Ocidental     África   Norte da África     0     0     0     0     0
# Iémen                 Ásia    Ásia Ocidental     1     2     1     6     0
# Zâmbia              África   África Oriental    11    17    11     7    16
# Zimbábue            África   África Oriental    72   114   102    44    32
#
# ...

# %%
anos = list(map(str,range(1980,2014)))

# %%
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
brasil = arquivo.loc["Brasil",anos]

# %%
brasil_dic = {"Anos" : brasil.index.tolist(), "Imigrantes" : brasil.values.tolist()}
dados_brasil = pd.DataFrame(brasil_dic)

# %%
dados_brasil
# Out:
#     Anos  Imigrantes
# 0   1980         211
# 1   1981         220
# 2   1982         192
# 3   1983         139
# 4   1984         145
# 5   1985         130
# 6   1986         205
# 7   1987         244
# 8   1988         394
# 9   1989         650
# 10  1990         650
# 11  1991         877
# 12  1992        1066
# 13  1993         866
# 14  1994         566
# 15  1995         572
# 16  1996         586
# 17  1997         591
# 18  1998         531
# 19  1999         626
# 20  2000         845
# 21  2001         847
# 22  2002         745
# 23  2003         839
# 24  2004         917
# 25  2005         969
# 26  2006        1181
# 27  2007        1746
# 28  2008        2138
# 29  2009        2509
# 30  2010        2598
# 31  2011        1508
# 32  2012        1642
# 33  2013        1714

# %%
america_sul = arquivo.query('Região == "América do Sul"').sort_values("Total", ascending=True)
america_sul
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Suriname   América Latina e o Caribe  América do Sul    15    10    21    12
# Paraguai   América Latina e o Caribe  América do Sul    45    26    32    40
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Uruguai    América Latina e o Caribe  América do Sul   128   132   146   105
# Equador    América Latina e o Caribe  América do Sul   238   207   184   155
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Venezuela  América Latina e o Caribe  América do Sul   103   117   174   124
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Peru       América Latina e o Caribe  América do Sul   317   456   401   241
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
# ...

# %%
plt.figure(figsize=(8,4))
plt.plot(dados_brasil["Anos"], dados_brasil["Imigrantes"])
plt.title("Imigraçao do Brasil para o Canada")
plt.xlabel("Ano")
plt.ylabel("Imigrantes")
plt.xticks(["1980","1985","1990","1995","2000", "2005","2010","2013"])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(dados_brasil["Anos"],dados_brasil["Imigrantes"],lw=3, color="g")
ax.set_title("Imigraçao do Brasil para o Canada",fontsize=18,loc="left")

ax.set_xlabel("Ano", fontsize=14)
ax.set_ylabel("Numero de Imigrantes",fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.grid()
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))
axs[0].plot(dados_brasil["Anos"],dados_brasil["Imigrantes"])
axs[0].set_title("Imigraçao do Brasil para o Canada")
axs[0].set_xlabel("Ano")
axs[0].set_ylabel("Imigrantes")
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))
axs[0].grid()


axs[1].boxplot(dados_brasil["Imigrantes"])
axs[1].set_title("Imigraçao do Brasil para o Canada")
axs[1].set_xlabel("Brasil")
axs[1].set_ylabel("Imigrantes")
axs[1].grid()
plt.show()

# %%
dados_brasil.describe()
# Out:
#         Imigrantes
# count    34.000000
# mean    872.323529
# std     663.401232
# min     130.000000
# 25%     428.250000
# 50%     697.500000
# 75%    1041.750000
# max    2598.000000

# %%
fig, axs = plt.subplots(2,2, figsize=(10,6))
fig.subplots_adjust(hspace=0.5,wspace=0.3)
fig.suptitle("Imigraçao do quatro maiores paises para o canada")

axs[0,0].plot(arquivo.loc["Brasil",anos])
axs[0,0].set_title("Brasil")

axs[0,1].plot(arquivo.loc["Colômbia",anos])
axs[0,1].set_title("Colombia")

axs[1,0].plot(arquivo.loc["Argentina", anos])
axs[1,0].set_title("Argentina")

axs[1,1].plot(arquivo.loc["Peru",anos])
axs[1,1].set_title("Peru")

for ax in axs.flat:
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))
for ax in axs.flat:
    ax.set_xlabel("Ano")
    ax.set_ylabel("Numero de imigrantes")

ymin = 0
ymax = 7000
for ax in axs.ravel():
    ax.set_ylim(ymin,ymax)
plt.show()

# %%
cores = []
for pais in america_sul.index:
    if pais == "Brasil":
        cores.append("green")
    else:
        cores.append("silver")
fig, ax = plt.subplots(figsize=(12, 5))
ax.barh(america_sul.index, america_sul['Total'], color=cores)
ax.set_title("Imigraçao da america do sul para o Canada",loc="left",fontsize=14)
ax.set_ylabel("")
ax.set_xlabel("Numero de Imigrantes", fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

for i,v in enumerate(america_sul["Total"]):
    ax.text(v +20, i , str(v), color="Black", fontsize=10,ha="left", va= "center")

ax.set_frame_on(False)
ax.get_xaxis().set_visible(False)
ax.tick_params(axis="both", which="both", length=0)
fig.savefig("Imigraçao grafico de Barra.png", transparent= False, dpi=300,bbox_inches="tight")
plt.show()

# %%
print(fig.canvas.get_supported_filetypes())
# Out:
# {'eps': 'Encapsulated Postscript', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'ps': 'Postscript', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format', 'webp': 'WebP Image Format'}

# %%
sns.set_theme()

# %%
top_10 = arquivo.sort_values("Total",ascending=False).head(10)
top_10
# Out:
#                                       Continente            Região   1980  \
# País
# Índia                                       Ásia       Sul da Ásia   8880
# China                                       Ásia     Ásia Oriental   5123
# Reino Unido e Irlanda do Norte            Europa   Norte da Europa  22045
# Filipinas                                   Ásia  Sudeste Asiático   6051
# Paquistão                                   Ásia       Sul da Ásia    978
# Estados Unidos da América       América do Norte  América do Norte   9378
# Irã                                         Ásia       Sul da Ásia   1172
# Sri Lanka                                   Ásia       Sul da Ásia    185
# República da Coreia                         Ásia     Ásia Oriental   1011
# Polônia                                   Europa   Europa Oriental    863
#
#                                  1981   1982   1983   1984  1985  1986   1987  \
# País
# ...

# %%
sns.barplot(data=top_10, x="Total", y=top_10.index)
# Out:
# <Axes: xlabel='Total', ylabel='País'>

# %%
ax = sns.barplot(data=top_10,  y=top_10.index, x="Total", orient="h")
ax.set(title="Paises com maior imigraçao para o canada",
      xlabel="numero de imigrantes",
      ylabel="")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax = sns.barplot(data=top_10, y=top_10.index, x="Total", orient="h")
ax.set_title("Paises com maior imigraçao para o canada", loc="left",fontsize=18)
ax.set_xlabel("numero de imigrantes", fontsize=14)
ax.set_xlabel("")
plt.show()

# %%
def gerar_grafico_paleta(palette):
    fig, ax = plt.subplots(figsize=(8,4))
    ax = sns.barplot(data=top_10, y=top_10.index, x="Total", orient="h", palette = palette)
    ax.set_title("Paises com maior imigraçao para o canada", loc="left",fontsize=18)
    ax.set_xlabel("numero de imigrantes", fontsize=14)
    ax.set_xlabel("")
    plt.show()

# %%
gerar_grafico_paleta("Blues")
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_24184\1045403799.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x="Total", orient="h", palette = palette)

# %%
gerar_grafico_paleta("rocket")
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_24184\1045403799.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x="Total", orient="h", palette = palette)

# %%
gerar_grafico_paleta("coolwarm_r")
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_24184\1045403799.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x="Total", orient="h", palette = palette)

# %%
gerar_grafico_paleta("tab10")
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_24184\1045403799.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x="Total", orient="h", palette = palette)

# %%
sns.set_theme(style="dark")
gerar_grafico_paleta("tab10")
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_24184\1045403799.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x="Total", orient="h", palette = palette)

# %%
sns.set_theme(style="whitegrid")
gerar_grafico_paleta("tab10")
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_24184\1045403799.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x="Total", orient="h", palette = palette)

# %%
sns.set_theme(style="white")
gerar_grafico_paleta("tab10")
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_24184\1045403799.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x="Total", orient="h", palette = palette)

# %%
sns.set_theme(style="ticks")
gerar_grafico_paleta("tab10")
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_24184\1045403799.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x="Total", orient="h", palette = palette)

# %%
import plotly.express as px

# %%
fig = px.line(dados_brasil, x='Anos', y='Imigrantes',
             title="Imigraçao para o brasil")
fig.update_traces(line_color="green", line_width=4)
fig.update_layout(width= 1000, height= 500, 
                 xaxis={"tickangle":-45},
                 font_family="Arial",
                 font_size=14,
                 font_color="grey",
                 title_font_color="black",
                 title_font_size=22,
                 xaxis_title= "Ano",
                 yaxis_title= "Numero de Imigrantes")
fig.show()

# %%
df_america_sul_clean = america_sul.drop(['Continente', 'Região', 'Total'], axis=1)
america_sul_final = df_america_sul_clean.T
america_sul_final
# Out:
# País  Suriname  Paraguai  Bolívia  Uruguai  Equador  Argentina  Venezuela  \
# 1980        15        45       44      128      238        368        103
# 1981        10        26       52      132      207        426        117
# 1982        21        32       42      146      184        626        174
# 1983        12        40       49      105      155        241        124
# 1984         5        48       38       90      179        237        142
# 1985        16        36       44       92      208        196        165
# 1986         7        34       79      137      240        213        179
# 1987        46        72      165      269      344        519        229
# 1988        16        53       63       99      265        374        279
# 1989        24        48       68      144      278        538        304
# 1990        26        56       71      111      552        678        344
# 1991        13        51      214      229      643        763        487
# ...

# %%
fig = px.line(america_sul_final, x=america_sul_final.index, y=america_sul_final.columns, color='País', 
              title='Imigração dos países da América do Sul para o Canadá de 1980 a 2013')
fig.update_layout(
    xaxis={'tickangle': -45},
    xaxis_title='Ano',
    yaxis_title='Número de imigrantes')

fig.show()

# %%
fig.write_html("Imigraçao para o canada.html")
