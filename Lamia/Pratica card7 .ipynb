# %%
#Aqui ele coloca um markdown e explica como faz para coloca-los

# %% [markdown]
# # Jupyter notebook example
# ## subtitle
# this is an example notebook
#
#     1 this is item 1
#
#     2 this is item 2
#
#     3 this is item 3

# %%
#Aqui ele faz um print normal para demonstrar como funciona o esquema por notes

# %%
print("hello viwers")
# Out:
# hello viwers

# %%
#Aqui ele faz toda o import de codigos nescessarios para criar a primeira aplicação

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import matplotlib

# %%
#Aqui ele desenha um grafico com base em funçoes matematicas como seno, pi e depois ele constroi o grafico

# %%
t= np.arange(0.0,2.0,0.01)
s = 1+ np.sin(2*np.pi * t)

fig, ax = plt.subplots()
ax.plot(t,s)

ax.set(xlabel ='time(s)',ylabel= 'voltage (mV)', title = 'About as simple as it gets, folks')
ax.grid()
